# %% [markdown]
# ## Triage sql from Matt

# %%
import nbimporter
from data_access import db_access as db

from data_access.db_access import display_data

from triage.pnc_reg import PNC_reg_summary_processing
from triage.pnc_reg import PNC_reg_throughput

from triage.video import Video_witness_timings

db.setup_connection('V-PW-ST04-FS1.lab.stl.local\CRM2016')

# %% [markdown]
# ### PNC reg summary processing

# %%
display_data(PNC_reg_summary_processing(2015,1000))
# Out:
#     yyyy  mm  MinProcessTime  MaxProcessTime  AvgProcessTime    cnt
# 0   2023   1               0              40              10   7835
# 1   2022  12               6             437              20   8187
# 2   2022  11               0             429              15  13889
# 3   2022  10               6              27              19   3393
# 4   2022   9              13              26              19    694
# 5   2022   8               0             928              20  27862
# 6   2022   7               2              52              20  53520
# 7   2022   6               6              36              19  12073
# 8   2022   5               5              26              19   4711
# 9   2022   4               6              26              19   1083
# 10  2022   2               6             299              27     16
# 11  2021  12               6              27              12      9
# 12  2021  11               6              27              10     15
# ...

# %% [markdown]
# ### PNC reg throughput

# %%
display_data(PNC_reg_throughput(2015))
# Out:
#     yyyy  mm  dailyMin  dailyMax  dailyAvg  totalForMonth
# 0   2023   1         2      3195       560           7853
# 1   2022  12       144       288       264           8187
# 2   2022  11         1      1465       695          13915
# 3   2022  10        27       576       308           3398
# 4   2022   9        42       224       139            698
# 5   2022   8       144      4658       901          27953
# 6   2022   7       720      3356      1726          53526
# 7   2022   6       216       730       402          12078
# 8   2022   5         8       360       196           4720
# 9   2022   4         1       144        72           1085
# 10  2022   2         1        10         3             41
# 11  2022   1         1        10         3             19
# 12  2021  12         1         5         2             15
# 13  2021  11         1         3         1             15
# 14  2021  10         1         1         1              2
# ...

# %% [markdown]
# ### Video witness timings

# %%
display_data(Video_witness_timings(2020,1000))
# Out:
#     yyyy  mm  MinProcessTime  MaxProcessTime  AvgProcessTime  cnt
# 0   2023   1               1               2               1    4
# 1   2022  12               2               2               2    2
# 2   2022  11               1               3               1   20
# 3   2022  10               1               8               2   25
# 4   2022   8               1               1               1    2
# 5   2022   7               2              21               8   13
# 6   2022   6               1               2               1   14
# 7   2022   5               1             101               9   23
# 8   2022   4               1               2               1    8
# 9   2022   2               1               2               1   14
# 10  2022   1               1               1               1    2
# 11  2021  12               1               1               1    4
# 12  2021  11               1               2               1   10
# ...
